# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.feature_selection
from sklearn.feature_selection import mutual_info_classif

file = 'heart.csv'
read = pd.read_csv( file )
data = pd.DataFrame( read )
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# # Age

# %%
data_x = data.drop( columns=['output'] )
mutual_info = mutual_info_classif( data_x, data['output'], discrete_features='auto' )
mi_scores = pd.Series( mutual_info, index=data_x.columns )
mi_scores
# Out:
# age         0.045412
# sex         0.040897
# cp          0.137640
# trtbps      0.000000
# chol        0.084747
# fbs         0.000000
# restecg     0.014781
# thalachh    0.068265
# exng        0.122100
# oldpeak     0.068630
# slp         0.049684
# caa         0.135476
# thall       0.131593
# dtype: float64

# %%
sns.swarmplot( data=data, x='output', y='age' )
# Out:
# <AxesSubplot:xlabel='output', ylabel='age'>

# %%
sns.swarmplot( data=data, x='output', y='fbs')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 65.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='fbs'>

# %%
sns.swarmplot( data=data, x='output', y='restecg')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='restecg'>

# %%
sns.swarmplot( data=data, x='output', y='trtbps')
# Out:
# <AxesSubplot:xlabel='output', ylabel='trtbps'>

# %%
sns.swarmplot( data=data, x='output', y='sex')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='sex'>

# %%
sns.swarmplot( data=data, x='output', y='chol')
# Out:
# <AxesSubplot:xlabel='output', ylabel='chol'>

# %%
sns.swarmplot( data=data, x='output', y='thalachh')
# Out:
# <AxesSubplot:xlabel='output', ylabel='thalachh'>

# %%
sns.swarmplot( data=data, x='output', y='cp')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='cp'>

# %%
sns.swarmplot( data=data, x='output', y='exng')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 63.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='exng'>

# %%
sns.swarmplot( data=data, x='output', y='oldpeak')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='oldpeak'>

# %%
sns.swarmplot( data=data, x='output', y='slp')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 64.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='slp'>

# %%
sns.swarmplot( data=data, x='output', y='caa')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 63.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='caa'>

# %%
sns.swarmplot( data=data, x='output', y='thall')
# Out:
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gdt31\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 65.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='output', ylabel='thall'>
